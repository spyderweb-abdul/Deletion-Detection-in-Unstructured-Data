# %% [markdown]
# <a href="https://colab.research.google.com/github/spyderweb-abdul/Deletion-Detection-in-Unstructured-Data/blob/main/gru_edge_reconstruction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os, sys
#from google.colab import drive
#drive.mount('/content/drive')
#nb_path = '/content/libraries'
sys.path.append('/content/drive/My Drive/Colab Notebooks/VGRNN/')
sys.path.append('/content/drive/My Drive/Colab Notebooks/')

#os.symlink('/content/drive/My Drive/Colab Notebooks', nb_path)
#sys.path.insert(0,nb_path)

# %%
from __future__ import absolute_import
from __future__ import division
from __future__ import print_function

import io
import math
import numpy as np
import torch
import torch.nn as nn
import torch.utils
import torch.utils.data
from torchvision import datasets, transforms
from torch.autograd import Variable
import matplotlib.pyplot as plt 
from scipy.ndimage import rotate
from torch.distributions.uniform import Uniform
from torch.distributions.normal import Normal
#from sklearn.datasets import fetch_mldata
# from torch_geometric import nn as tgnn
from input_data import load_data
from preprocessing import preprocess_graph, construct_feed_dict, sparse_to_tuple, mask_test_edges
import scipy.sparse as sp
from scipy.linalg import block_diag
from torch.nn.parameter import Parameter
from torch.nn.modules.module import Module
import tarfile
import torch.nn.functional as F
import copy
import time

#!pip uninstall torch-scatter torch-sparse torch-geometric
# !pip install -q torch-scatter -f https://pytorch-geometric.com/whl/torch-1.6.0+cu102.html
# !pip install -q torch-sparse -f https://pytorch-geometric.com/whl/torch-1.6.0+cu102.html
# !pip install -q torch-geometric

import torch_scatter
from torch_scatter import scatter_mean, scatter_max, scatter_add
from torch_geometric.utils import remove_self_loops, add_self_loops, degree, segregate_self_loops
#from torch_geometric.datasets import Planetoid
import networkx as nx
import scipy.io as sio

import inspect
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, roc_auc_score, average_precision_score
from sklearn.manifold import TSNE

import copy
import pickle
# !pip install sparse
import sparse

import time
import datetime
from datetime import timedelta
import pandas as pd

from torch.utils.tensorboard import SummaryWriter

from warnings import simplefilter
# ignore all future warnings
simplefilter(action='ignore', category=FutureWarning)

#print(torch.__version__)
# Out:
# Requirement already satisfied: sparse in /usr/local/lib/python3.7/dist-packages (0.13.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sparse) (1.19.5)
# Requirement already satisfied: scipy>=0.19 in /usr/local/lib/python3.7/dist-packages (from sparse) (1.4.1)
# Requirement already satisfied: numba>=0.49 in /usr/local/lib/python3.7/dist-packages (from sparse) (0.51.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->sparse) (57.4.0)
# Requirement already satisfied: llvmlite<0.35,>=0.34.0.dev0 in /usr/local/lib/python3.7/dist-packages (from numba>=0.49->sparse) (0.34.0)

# %%
seed = 3
np.random.seed(seed)


# utility functions

def uniform(size, tensor):
    stdv = 1.0 / math.sqrt(size)
    if tensor is not None:
        tensor.data.uniform_(-stdv, stdv)


def glorot(tensor):
    stdv = math.sqrt(6.0 / (tensor.size(0) + tensor.size(1)))
    if tensor is not None:
        tensor.data.uniform_(-stdv, stdv)


def zeros(tensor):
    if tensor is not None:
        tensor.data.fill_(0)


def ones(tensor):
    if tensor is not None:
        tensor.data.fill_(1)


def reset(nn):
    def _reset(item):
        if hasattr(item, 'reset_parameters'):
            item.reset_parameters()

    if nn is not None:
        if hasattr(nn, 'children') and len(list(nn.children())) > 0:
            for item in nn.children():
                _reset(item)
        else:
            _reset(nn)

def tuple_to_array(lot):
    out = np.array(list(lot[0]))
    for i in range(1, len(lot)):
        out = np.vstack((out, np.array(list(lot[i]))))
    
    return out

# %%
# masking functions

def mask_edges_det(adjs_list):

    adj_train_l, train_edges_l, val_edges_l = [], [], []
    val_edges_false_l, test_edges_l, test_edges_false_l = [], [], []
    edges_list = []
    for i in range(0, len(adjs_list)):
        # Function to build test set with 10% positive links
        # NOTE: Splits are randomized and results might slightly deviate from reported numbers in the paper.
        
        adj = adjs_list[i]
        # Remove diagonal elements
        adj = adj - sp.dia_matrix((adj.diagonal()[np.newaxis, :], [0]), shape=adj.shape)
        adj.eliminate_zeros()

        # Check that diag is zero:
        assert np.diag(adj.todense()).sum() == 0
        
        #get the upper trianglar portion of the matrix.
        adj_triu = sp.triu(adj)

        #convert the matrix into a tuple of the format: ((([1, 10]), ([1, 1, 1,..., 1, 1, 1])),...)
        adj_tuple = sparse_to_tuple(adj_triu)

        #get only the 0 index of the tuple. Returns as list: [[1 10],[1 12],[1 4],[20 25]]
        #shape: (n, 2)
        edges = adj_tuple[0]

        #convert the adj sparse matrix to tuple and return the result of the 0 index of the tuple
        edges_all = sparse_to_tuple(adj)[0]

        #get the number of test set: row number(n)/10
        num_test = int(np.floor(edges.shape[0] / 10.))
      
        #get the number of the validation set: row number(n)/20
        num_val = int(np.floor(edges.shape[0] / 20.))
    
        #list numbers of edge index based on the row axis of the edges
        #all_edge_idx = range(edges.shape[0])
        all_edge_idx = list(range(edges.shape[0]))

        #randomize the result
        np.random.shuffle(all_edge_idx)

        #get validation edge index from the randomized edge list. Extract only numbers equal to num_val
        val_edge_idx = all_edge_idx[:num_val]

        #get test edge index from the randomized edge list.
        #Extract only numbers equal to [num_val : (num_val + num_test)]
        test_edge_idx = all_edge_idx[num_val:(num_val + num_test)]

        #get the main test edge set by extracting values fom the edge list indexed by the test_edge_idx list
        test_edges = edges[test_edge_idx]
        
        #get the main validation edge set by extracting values fom the edge list indexed by the test_edge_idx list
        val_edges = edges[val_edge_idx]

        #delete the stacked test and validation edge set (along the axis=0) from the list of edges. 
        #This will be the training set
        # [[162 165], [162 169], [162 172], [171 174]]

        train_edges = np.delete(edges, np.hstack([test_edge_idx, val_edge_idx]), axis=0)
        
        #append the list of main edges
        edges_list.append(edges)
        
        def ismember(a, b, tol=5):
            #Test whether all array elements along a given axis evaluate to True. (np.all)
            rows_close = np.all(np.round(a - b[:, None], tol) == 0, axis=-1)
            return np.any(rows_close)  #np.any evaluate whether any elements evaluate to True

        #get false edge test set
        test_edges_false = []
        #Do while test_egde_false list length is still less than the tst_edge list
        while len(test_edges_false) < len(test_edges):
            #get random integers between 0 (lower) and the row size of the adj (higher)
            idx_i = np.random.randint(0, adj.shape[0])
            idx_j = np.random.randint(0, adj.shape[0])

            #if right and left values are equal, go back to the top loop
            if idx_i == idx_j:
                continue
            #if the tuple of the 2 values are part of edges_all (returns a bool), back to top
            if ismember([idx_i, idx_j], edges_all):
                continue
            #if the empty test_edges_false list is not None, check the conditions
            if test_edges_false:
                #if the tuple of the 2 values are part of test_edges_false list, back to top
                if ismember([idx_j, idx_i], np.array(test_edges_false)):
                    continue
                if ismember([idx_i, idx_j], np.array(test_edges_false)):
                    continue
            #append result to the test_edges_false list
            test_edges_false.append([idx_i, idx_j])  #result sample: [[19, 2], [177, 163], [15, 119], [3, 155],...] 

        
        #get false validation edge set    
        val_edges_false = []
        while len(val_edges_false) < len(val_edges):
            idx_i = np.random.randint(0, adj.shape[0])
            idx_j = np.random.randint(0, adj.shape[0])
            if idx_i == idx_j:
                continue
            if ismember([idx_i, idx_j], train_edges):
                continue
            if ismember([idx_j, idx_i], train_edges):
                continue
            if ismember([idx_i, idx_j], val_edges):
                continue
            if ismember([idx_j, idx_i], val_edges):
                continue
            if val_edges_false:
                if ismember([idx_j, idx_i], np.array(val_edges_false)):
                    continue
                if ismember([idx_i, idx_j], np.array(val_edges_false)):
                    continue
            val_edges_false.append([idx_i, idx_j])

        r""" The assert keyword lets you test if a condition in your code returns True, 
        if not, the program will raise an AssertionError.

        #we assert the truthfulness of these conditions. 
        #check to confirm that the values (arg: 1) are bitwise NOT (tilde)
        #in the set of values (arg: 2) in the other list."""

        assert ~ismember(test_edges_false, edges_all)
        assert ~ismember(val_edges_false, edges_all)
        assert ~ismember(val_edges, train_edges)
        assert ~ismember(test_edges, train_edges)
        assert ~ismember(val_edges, test_edges)

        #get np.ones of elements of the row size of the train_edges
        data = np.ones(train_edges.shape[0])

        # Re-build adj matrix for the training set
        r""" [ : , 0 ] means (more or less) [ first_row:last_row , column_0 ]. 
        If you have a 2-dimensional list/matrix/array, this notation will give you all 
        the values in column 0 (from all rows)."""

        adj_train = sp.csr_matrix((data, (train_edges[:, 0], train_edges[:, 1])), shape=adj.shape)

        #add the new adjacency matrix to its transpose
        adj_train = adj_train + adj_train.T

        #fill all the initialised list
        adj_train_l.append(adj_train)
        train_edges_l.append(train_edges)
        val_edges_l.append(val_edges)
        test_edges_l.append(test_edges)
        val_edges_false_l.append(val_edges_false)
        test_edges_false_l.append(test_edges_false)

    # NOTE: these edge lists only contain single direction of edge!
    return adj_train_l, train_edges_l, val_edges_l, val_edges_false_l, test_edges_l, test_edges_false_l

# %%
# loading data

path = 'drive/My Drive/Colab Notebooks/VGRNN/data/'
# # Enron dataset
with open(path+'enron_data/enron_adj_sparse_matrix.pickle', 'rb') as handle:
     adj_sparse_matrix = pickle.load(handle)

with open(path+'enron_data/enron_adj_dense_matrix.pickle', 'rb') as handle:
     adj_dense_matrix = pickle.load(handle)

with open(path+'enron_data/enron_edge_attribute_matrix.pickle', 'rb') as handle:
     edge_attr_matrix = pickle.load(handle)

with open(path+'enron_data/enron_node_attribute_matrix.pickle', 'rb') as handle:
     node_attr_matrix = pickle.load(handle)

adj_sparse_matrix = adj_sparse_matrix[7:34]                       #80
adj_dense_matrix = adj_dense_matrix[7:34]            #80
edge_attr_matrix = edge_attr_matrix[7:34]            #80
node_attr_matrix = node_attr_matrix[7:34]            #80


#print(adj_sparse_matrix)
outs = mask_edges_det(adj_sparse_matrix)

#reconstructed adjacency matrix of the training set
adj_train_l = outs[0]                 #80

#List of training edge set
train_edges_l = outs[1]               #80

#List of validation edge set
val_edges_l = outs[2]                 #80

#List of false validation edge set(i.e., never exist)
val_edges_false_l = outs[3]           #80

#List of test edge set
test_edges_l = outs[4]                #80

#List of false test edge set 
test_edges_false_l = outs[5]          #80

# creating edge list
edge_idx_list = []                    #80

for i in range(len(train_edges_l)):
    edge_idx_list.append(torch.tensor(np.transpose(train_edges_l[i]), dtype=torch.long))

#print(edge_idx_list)

# %%
# layers

class E_GCN_Conv(nn.Module):
    def __init__(self, in_channels, out_channels, act=F.relu, improved=True, bias=True, num_channels=10, aggr='sum'):
        super(E_GCN_Conv, self).__init__()

        self.in_channels = in_channels            #[64]
        self.out_channels = out_channels          #[32]
        self.act = act
        self.num_channels = num_channels

        self.weight = Parameter(torch.Tensor(in_channels, out_channels, num_channels))

        if bias:
            self.bias = Parameter(torch.Tensor(out_channels, num_channels))
        else:
            self.register_parameter('bias', None)

        self.reset_parameters()

        if (aggr == 'concat'):
            self.aggr = 'concat'
            self.last_ops = nn.Linear(self.out_channels * self.num_channels, self.out_channels)
        elif (aggr == 'sum'):
            self.aggr = 'sum'
            self.last_ops = nn.Linear(self.out_channels, self.out_channels)
        

    def reset_parameters(self):
        glorot(self.weight)
        zeros(self.bias)

    
    def forward(self, x, edge_index, edge_attr):

        #add or remove node self loop. We remove in our case
        edge_index, edge_attr = remove_self_loops(edge_index, edge_attr)

        
        #edge index rows and column representation
        row, col = edge_index     #[21]

        #normalize the adjacency matrix
        #deg = scatter_add(edge_attr, row, dim=0, dim_size=x.size(0))
        deg = degree(col, x.size(0), dtype=x.dtype)
        deg_inv_sqrt = deg.pow(-0.5)
        deg_inv_sqrt[deg_inv_sqrt == float('inf')] = 0

        #reshape the row and column vectors
        deg_inv_sqrt_row = deg_inv_sqrt[row].view(-1, 1)      #[[1.0000],[1.0000]]
        deg_inv_sqrt_col = deg_inv_sqrt[col].view(-1, 1)      #[[0.5774],[0.0000]]

        #multiply row and col vectors with edge weights (We replace the adjacency matrix with the edge tensor)
        norm_edge = deg_inv_sqrt_row * edge_attr * deg_inv_sqrt_col     #size([edge_index[row/col] No., 14])


        #Slice and list the normalized vectors based on the nu. of channels
        norm = []
        for i in range(0, edge_attr.size()[1]):
            norm.append(norm_edge[:, i:i+1])

        node_state_list = []
        #for each edge channels, we perform a weoghted convolution with edge weights as co-efficient
        for c in range(self.num_channels):
            if self.in_channels > self.out_channels:

                #if the weight matrix is not none
                if self.weight is not None:
                    #matrix product of the node (hidden state) with the weight matrix
                    weighted_nodes = torch.matmul(x, self.weight[:, :, c])      #(size[149, 32])
                else:
                    #otherwise, hidden state remains same
                    weighted_nodes = x
                
                #if vectors are normalized
                if norm is not None: 
                    #multiply each element in the each channels of the norm with weighted hidden state             
                    weighted_conv = torch.mul(norm[c], weighted_nodes[row])      #size(21, 32)

                    #propagate messages through all edges and update the nodes
                    weighted_conv_sum = scatter_add(weighted_conv, col, dim=0, dim_size=x.size(0)) #size(149, 32)
                else:
                    weighted_conv_sum = scatter_add(weighted_nodes[row], col, dim=0, dim_size=x.size(0))

                channel_node_state = weighted_conv_sum

            else:
                if norm is not None:
                    unweighted_conv = torch.mul(norm[c], x[row])
                    unweighted_conv_sum = scatter_add(unweighted_conv, col, dim=0, dim_size=x.size(0))
                else:
                    unweighted_conv_sum = scatter_add(x[row], col, dim=0, dim_size=x.size(0))
                
                if self.weight is not None:
                    channel_node_state = torch.matmul(unweighted_conv_sum.float(), self.weight[:, :, c])
            
            #add linear bias if True
            if self.bias is not None:
                channel_node_state = channel_node_state + self.bias[:, c]
            
            #pass param through a linear activation function
            channel_node_state = self.act(channel_node_state)
            #append each channel to node state list
            node_state_list.append(channel_node_state)        #size(N, 32/16)

        #we consider two aggregation method across each channels of the edge weights
        #1. Sum aggregation method 
        if (self.aggr == 'sum'):
            node_states = torch.stack(node_state_list, dim=1).sum(1).float()     #[N, 32]
        #2. Concat aggregation method               
        elif (self.aggr == 'concat'): 
            node_states = torch.cat(node_state_list, dim=1).float()
            
        #pass aggregated vectors through a flexible linear transformation layer      
        out = self.last_ops(node_states)                        #size(N, 32/16)

        return out

    def __repr__(self):
        return '{}({}, {})'.format(self.__class__.__name__, self.in_channels, 
                                   self.out_channels, self.num_channels)

# %%
class gru_gcn(nn.Module):
    def __init__(self, input_size, hidden_size, n_layer, bias=True):
        super(gru_gcn, self).__init__()

        self.hidden_size = hidden_size
        self.n_layer = n_layer
        
        # gru weights
        self.weight_xz = []
        self.weight_hz = []
        self.weight_xr = []
        self.weight_hr = []
        self.weight_xh = []
        self.weight_hh = []
        
        for i in range(self.n_layer):
            if i==0:
                #update Gate
                self.weight_xz.append(E_GCN_Conv(input_size, hidden_size, act=lambda x:x, bias=bias))
                self.weight_hz.append(E_GCN_Conv(hidden_size, hidden_size, act=lambda x:x, bias=bias))
                #reset gate
                self.weight_xr.append(E_GCN_Conv(input_size, hidden_size, act=lambda x:x, bias=bias))
                self.weight_hr.append(E_GCN_Conv(hidden_size, hidden_size, act=lambda x:x, bias=bias))
                #Candidate state
                self.weight_xh.append(E_GCN_Conv(input_size, hidden_size, act=lambda x:x, bias=bias))
                self.weight_hh.append(E_GCN_Conv(hidden_size, hidden_size, act=lambda x:x, bias=bias))
            else:
                #update gate
                self.weight_xz.append(E_GCN_Conv(hidden_size, hidden_size, act=lambda x:x, bias=bias))
                self.weight_hz.append(E_GCN_Conv(hidden_size, hidden_size, act=lambda x:x, bias=bias))
                #reset gate
                self.weight_xr.append(E_GCN_Conv(hidden_size, hidden_size, act=lambda x:x, bias=bias))
                self.weight_hr.append(E_GCN_Conv(hidden_size, hidden_size, act=lambda x:x, bias=bias))
                #candidate state
                self.weight_xh.append(E_GCN_Conv(hidden_size, hidden_size, act=lambda x:x, bias=bias))
                self.weight_hh.append(E_GCN_Conv(hidden_size, hidden_size, act=lambda x:x, bias=bias))
    
    def forward(self, inp, edge_index, edge_tensor, h):
        h_out = torch.zeros(h.size())
        for i in range(self.n_layer):
            if i==0:
                #update gate computation
                z_g = torch.sigmoid(self.weight_xz[i](inp, edge_index, edge_tensor) + self.weight_hz[i](h[i], edge_index, edge_tensor))
                #reset gate computation
                r_g = torch.sigmoid(self.weight_xr[i](inp, edge_index, edge_tensor) + self.weight_hr[i](h[i], edge_index, edge_tensor))
                #candidate state computation
                h_tilde_g = torch.tanh(self.weight_xh[i](inp, edge_index, edge_tensor) + self.weight_hh[i](r_g * h[i], edge_index, edge_tensor))
                #hidden state
                h_out[i] = z_g * h[i][0: inp.size(0)] + (1 - z_g) * h_tilde_g

            else:
                #update gate comp.
                z_g = torch.sigmoid(self.weight_xz[i](h_out[i-1], edge_index, edge_tensor) + self.weight_hz[i](h[i], edge_index, edge_tensor))
                #reset state comp.
                r_g = torch.sigmoid(self.weight_xr[i](h_out[i-1], edge_index, edge_tensor) + self.weight_hr[i](h[i], edge_index, edge_tensor))
                #candidate state comp.
                h_tilde_g = torch.tanh(self.weight_xh[i](h_out[i-1], edge_index, edge_tensor) + self.weight_hh[i](r_g * h[i], edge_index, edge_tensor))
                #hidden state
                h_out[i] = z_g * h[i] + (1 - z_g) * h_tilde_g
   
        
        out = h_out
        return out, h_out

# %%
# VGRNN model

class VGAE_Edge(nn.Module):
    def __init__(self, node_feat_dim, hidden_dim, latent_var_dim, n_layers, edge_feat_dim, eps, conv='GCN', bias=False):
        super(VGAE_Edge, self).__init__()
        
        #input dimension
        self.node_feat_dim = node_feat_dim        
        self.eps = eps
        #hidden_layer dim.
        self.hidden_dim = hidden_dim        #32
        #latent variable dim.
        self.latent_var_dim = latent_var_dim        #10
        self.n_layers = n_layers   #1
        self.edge_feat_dim = edge_feat_dim
       
        if conv == 'GCN':
            #flexible sequential neural network linear transformations
            self.input_emb = nn.Sequential(nn.Linear(node_feat_dim, hidden_dim))
 
            #recurrent neural networks model function
            self.rnn = gru_gcn(hidden_dim + hidden_dim, hidden_dim, n_layers, bias)

            self.output_emb = nn.Sequential(nn.Linear(hidden_dim, latent_var_dim), nn.Softmax(dim=1))

          
    def forward(self, x, edge_idx_list, edge_attr_matrix, hidden_in=None):

        #assert the length of edge matrix = elngth of the edge indices
        assert len(edge_attr_matrix) == len(edge_idx_list)

        #initialize params
        l2_loss = 0
        output_list = []
       
        #hidden var will be none in the first set of operations
        if hidden_in is None:
            #so we create a matrix of zeros as initial representation
            h = torch.zeros(self.n_layers, x.size(1), self.hidden_dim)  #size([1, 149, 32])
        else:
            #hidden var here will be the recurrent vectors
            h = hidden_in        


        for t in range(x.size(0)):       #x.size(0) = 60

            #edge indices at time t    
            edge_idx_list_t = edge_idx_list[t]
            edge_tensor_t = (edge_attr_matrix[t][edge_idx_list_t[0], edge_idx_list_t[1]])    
   
            #encoder
            input_emb_t = self.input_emb(x[t].float())              #[149, 32]
            #recurrence
            enc_out, h = self.rnn(torch.cat([input_emb_t, h[-1]], 1), edge_idx_list_t, edge_tensor_t, h)       #[1, 149, 32]            
            #gru_decoder
            enc_out_t = self.output_emb(enc_out[-1])         #[149, 16]

            decoder_t = self.dec(enc_out_t, edge_idx_list_t)

            l2_loss += self._l2_norm(decoder_t, edge_tensor_t)

            output_list.append(enc_out_t)

        return l2_loss, output_list, h
    
    
    def reset_parameters(self, stdv=1e-1):
        for weight in self.parameters():
            weight.data.normal_(0, stdv)

    #decoder function
    def dec(self, z, edge_index):
        #input features have dimension = the col sizes of Zi and Zj 
        in_feat = int(z.size(1))
        #output feature has the col size of edge tensors (14 or 10)
        out_feat = int(self.edge_feat_dim)
        #output = neural network decoder
        outputs = Decoder(in_feat, out_feat, act=lambda x:x)(z, edge_index)
        return outputs

    def _init_weights(self, stdv):
        pass    

    def regularizer(self, samples_size, features_size, lambda_value=0.01):

        m = samples_size
        n = features_size
        W = torch.randn(m, n)

        reg_term = (lambda_value / (2 * m)) * torch.sum(torch.square(W))
        #print(reg_term)
        return reg_term

    def _l2_norm(self, pred, actual):
        x_size_row = actual.size(0)
        x_size_col = actual.size(1)

        l2_reg = self.regularizer(x_size_row, x_size_col)

        loss = nn.MSELoss(reduction='mean')
        l2_loss = loss(input=pred.float(), target=actual.float())
        l2_loss_val = (1.0 / x_size_row) * l2_loss
        l2_norm = l2_loss_val #+ l2_reg

        return l2_norm

# %%
class Decoder(nn.Module):
    def __init__(self, in_feat, out_feat, act=torch.sigmoid):
        super(Decoder, self).__init__()        

        self.act = act
        self.in_feat = in_feat
        self.out_feat = out_feat
        self.edge_nn = nn.Linear(self.in_feat*2, self.out_feat, bias=False)

    def forward(self, z, edge_index):
        z = F.dropout(z, p=0., training=True)

        z0 = z[edge_index[0]]
        z1 = z[edge_index[1]]

        embs = torch.cat([z0, z1], dim=-1)

        edge_emb = self.edge_nn(embs)                   #size[N, 10]
        #print(edge_emb.size())
        return edge_emb

# %%
r""" Calculate and evaluate the Area Under (Receiver Operating Characteristic) Curve 
     and the Average Precision (AP) """

# evaluation function

def get_edge_eval_scores(edges_pos, edges_neg, edge_attr_matrix, edge_feat_dim, edge_emb):
    
    mse, rmse = [], []
    mae, mape = [], []

    in_channel = edge_emb[0].size(1)
    out_channel = edge_feat_dim 

    nn_layer = nn.Linear(in_channel, out_channel, bias=False)

    for i in range(len(edges_pos)):
        
        # Predict on test set of edges
        #explicitly remove the computational graph of the tensor 
        #(from gradient descent) with detach and change back to numpy
        emb = edge_emb[i].detach().numpy()

        z_emb = torch.tensor(emb)

        #edge tensor matrix
        edge_attr_mat = edge_attr_matrix[i]
       
        #initialize predicted edge list
        pred_pos_edge_list, pos_edge_list = [], []

        for e in edges_pos[i]:
  
            z_i = z_emb[e[0]]
            z_j = z_emb[e[1]]

            cat_embs = (z_i * z_j) 
            pos_embs_var = nn_layer(cat_embs).detach().numpy()
            #append the sigmoid computation of the reconstructed embedding matrix
            #Note: we can also consider without sigmoid as our task is regression like
            pred_pos_edge_list.append(pos_embs_var)
            #positive edge tensor
            pos_edge_list.append((edge_attr_mat[e[0], e[1]]))         
 
        pred_neg_edge_list, neg_edge_list = [], []

        for e in edges_neg[i]:

            z_i = z_emb[e[0]]
            z_j = z_emb[e[1]]

            cat_embs = (z_i * z_j)
            neg_embs_var = nn_layer(cat_embs).detach().numpy()
            pred_neg_edge_list.append(neg_embs_var)  

            neg_edge_list.append((edge_attr_mat[e[0], e[1]]))

        #stack up the positive and negative predicted features
        pred_all_edges = np.hstack([pred_pos_edge_list, pred_neg_edge_list])    

        #for error free mean square eval
        pos_edges = [t.detach().numpy() for t in pos_edge_list]
        neg_edges = [t.detach().numpy() for t in neg_edge_list]

        #stack up all positive and negative features
        all_true_edges = np.hstack([pos_edges, neg_edges])

        #evaluate the mean square error loss of the ground truth and predicted values
        mse.append(mean_squared_error(all_true_edges, pred_all_edges))
        rmse.append(mean_squared_error(all_true_edges, pred_all_edges, squared=False))
        mae.append(mean_absolute_error(all_true_edges, pred_all_edges))
        mape.append(mean_absolute_error(all_true_edges, pred_all_edges)*100)

    return mse, rmse, mae, mape, pos_edge_list, neg_edge_list, pred_pos_edge_list, pred_neg_edge_list

# %%
# hyperparameters

hidden_dim = 32
latent_var_dim = 16
n_layers =  1
clip = 10
learning_rate = 1e-2
num_nodes = node_attr_matrix[0].shape[1]
node_feat_dim = num_nodes
edge_feat_dim = 10
timesteps_len = len(train_edges_l)  #27
eps = 1e-10
conv_type='GCN'

# creating input tensors
node_attr = torch.stack(node_attr_matrix)   #[80, 149, 6]
#print(node_attr.size())

# building model
model = VGAE_Edge(node_feat_dim, hidden_dim, latent_var_dim, n_layers, edge_feat_dim, eps, conv=conv_type, bias=True)
optimizer = torch.optim.Adam(model.parameters(), lr=learning_rate)

#print(model)

# training
timesteps_init = 0
#25% of 36
timesteps_end = timesteps_len - 1      #27
test_init = 0

#writer = SummaryWriter('drive/MyDrive/Colab Notebooks/VGRNN/tensorboard_log/' + datetime.datetime.now().strftime("%Y%m%d-%H%M%S"))

start_time = time.monotonic()
for k in range(1000):
    optimizer.zero_grad()

    l2_loss, _, hidden_state = model(node_attr[timesteps_init:timesteps_end]
                                                , edge_idx_list[timesteps_init:timesteps_end]
                                                , edge_attr_matrix[timesteps_init:timesteps_end]
                                                )
    loss = l2_loss
    loss.backward()
    optimizer.step()
    
    nn.utils.clip_grad_norm_(model.parameters(), clip)
    
    if k > test_init:
        l2_loss, edge_dec, _ = model(node_attr[timesteps_end:timesteps_len]
                                              , edge_idx_list[timesteps_end:timesteps_len]
                                              , edge_attr_matrix[timesteps_end:timesteps_len]
                                              , hidden_state)
        #print(pos)
        #print('\n', pred)
        mse_val, rmse_val, mae_val, mape_val, pos, neg, pred_pos, pred_neg = get_edge_eval_scores(
                                                          val_edges_l[timesteps_end:timesteps_len]
                                                        , val_edges_false_l[timesteps_end:timesteps_len]
                                                        , edge_attr_matrix[timesteps_end:timesteps_len]
                                                        , edge_feat_dim
                                                        , edge_dec
                                                        )

        mse_test, rmse_test, mae_test, mape_test, pos, neg, pred_pos, pred_neg = get_edge_eval_scores(
                                                          test_edges_l[timesteps_end:timesteps_len]
                                                        , test_edges_false_l[timesteps_end:timesteps_len]
                                                        , edge_attr_matrix[timesteps_end:timesteps_len]
                                                        , edge_feat_dim
                                                        , edge_dec
                                                        )        


    #Note: Prior mean reduces the loss than the decoded variables. 
    print('********************************************************')
    print('epoch: ', k)
    print('\nLOSS => l2_loss: {} | loss: {}'.format(round(l2_loss.mean().item(), 4)
                                                          , round(loss.mean().item(), 4)
                                                          ))
    #writer.add_scalar("Loss/train", loss.mean().item(), k)
    if k > test_init:
        #writer.add_scalar("validation mean_score", np.mean(np.array(mse_val)), k)
        #writer.add_scalar("test mean_score", np.mean(np.array(mse_test)), k)

        
        print('\nEDGE RECONSTRUCTION VAL => mse: {} | rmse: {} | mae: {} | mape: {}'.format(
                                                                            round(np.mean(np.array(mse_val)), 4)
                                                                          , round(np.mean(np.array(rmse_val)), 4)
                                                                          , round(np.mean(np.array(mae_val)), 4)
                                                                          , round(np.mean(np.array(mape_val)), 4)
                                                                          ))
        print('\nEDGE RECONSTRUCTION TEST => mse: {} | rmse: {} | mae: {} | mape: {}'.format(
                                                                            round(np.mean(np.array(mse_test)), 4)
                                                                          , round(np.mean(np.array(rmse_test)), 4)
                                                                          , round(np.mean(np.array(mae_test)), 4)
                                                                          , round(np.mean(np.array(mape_test)), 4)
                                                                          ))
#print('Pos: ', pos)                                                                     
#print('Pos_Pred: ', pred_pos) 
#print('\nNeg: ', neg)
#print('Neg Pred: ', pred_neg)           
#writer.flush() 
#writer.close()   
end_time = time.monotonic()
print('Total Execution Time: {}'.format(timedelta(seconds=end_time - start_time)))

#!pip install tensorboard
#!tensorboard --logdir='drive/MyDrive/Colab Notebooks/VGRNN/tensorboard_log/'
# Out:
# Streaming output truncated to the last 5000 lines.
# epoch:  375
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.095 | mae: 0.0512 | mape: 5.1215
#
# EDGE RECONSTRUCTION TEST => mse: 0.0098 | rmse: 0.0992 | mae: 0.0504 | mape: 5.0414
# ********************************************************
# epoch:  376
#
# LOSS => l2_loss: 0.0001 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0949 | mae: 0.051 | mape: 5.1007
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0512 | mape: 5.1236
# ********************************************************
# epoch:  377
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0957 | mae: 0.0516 | mape: 5.1563
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1002 | mae: 0.0516 | mape: 5.1583
# ********************************************************
# epoch:  378
#
# LOSS => l2_loss: 0.0001 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0955 | mae: 0.0511 | mape: 5.1054
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0993 | mae: 0.051 | mape: 5.1049
# ********************************************************
# epoch:  379
#
# LOSS => l2_loss: 0.0002 | loss: 0.0047
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0518 | mape: 5.1831
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.0508 | mape: 5.0756
# ********************************************************
# epoch:  380
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0946 | mae: 0.0513 | mape: 5.1251
#
# EDGE RECONSTRUCTION TEST => mse: 0.0102 | rmse: 0.1008 | mae: 0.0519 | mape: 5.1942
# ********************************************************
# epoch:  381
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0957 | mae: 0.0522 | mape: 5.2157
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1002 | mae: 0.0518 | mape: 5.177
# ********************************************************
# epoch:  382
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.095 | mae: 0.0515 | mape: 5.1468
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.051 | mape: 5.0983
# ********************************************************
# epoch:  383
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0957 | mae: 0.0513 | mape: 5.1348
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1004 | mae: 0.0517 | mape: 5.1679
# ********************************************************
# epoch:  384
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.051 | mape: 5.1018
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1002 | mae: 0.0515 | mape: 5.1534
# ********************************************************
# epoch:  385
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0947 | mae: 0.0508 | mape: 5.0787
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1003 | mae: 0.0523 | mape: 5.2279
# ********************************************************
# epoch:  386
#
# LOSS => l2_loss: 0.0001 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0961 | mae: 0.0523 | mape: 5.227
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.0513 | mape: 5.131
# ********************************************************
# epoch:  387
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0949 | mae: 0.0507 | mape: 5.07
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.0509 | mape: 5.088
# ********************************************************
# epoch:  388
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0514 | mape: 5.1379
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1004 | mae: 0.0514 | mape: 5.1387
# ********************************************************
# epoch:  389
#
# LOSS => l2_loss: 0.0001 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.095 | mae: 0.0513 | mape: 5.133
#
# EDGE RECONSTRUCTION TEST => mse: 0.0102 | rmse: 0.1008 | mae: 0.0518 | mape: 5.1776
# ********************************************************
# epoch:  390
#
# LOSS => l2_loss: 0.0001 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.0513 | mape: 5.1339
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0995 | mae: 0.0506 | mape: 5.0613
# ********************************************************
# epoch:  391
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0947 | mae: 0.0508 | mape: 5.0796
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.051 | mape: 5.0975
# ********************************************************
# epoch:  392
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0956 | mae: 0.0514 | mape: 5.1383
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.0513 | mape: 5.129
# ********************************************************
# epoch:  393
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0951 | mae: 0.0513 | mape: 5.1269
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.0511 | mape: 5.1054
# ********************************************************
# epoch:  394
#
# LOSS => l2_loss: 0.0001 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.0514 | mape: 5.1426
#
# EDGE RECONSTRUCTION TEST => mse: 0.0097 | rmse: 0.0987 | mae: 0.0505 | mape: 5.0509
# ********************************************************
# epoch:  395
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0958 | mae: 0.0515 | mape: 5.1493
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1001 | mae: 0.0511 | mape: 5.1123
# ********************************************************
# epoch:  396
#
# LOSS => l2_loss: 0.0001 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0515 | mape: 5.1488
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1006 | mae: 0.0518 | mape: 5.1761
# ********************************************************
# epoch:  397
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0951 | mae: 0.0513 | mape: 5.1299
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.0519 | mape: 5.1898
# ********************************************************
# epoch:  398
#
# LOSS => l2_loss: 0.0001 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0518 | mape: 5.1819
#
# EDGE RECONSTRUCTION TEST => mse: 0.0098 | rmse: 0.0991 | mae: 0.0509 | mape: 5.0875
# ********************************************************
# epoch:  399
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.095 | mae: 0.0513 | mape: 5.1323
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.0514 | mape: 5.1392
# ********************************************************
# epoch:  400
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0951 | mae: 0.0512 | mape: 5.1191
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1001 | mae: 0.0514 | mape: 5.1439
# ********************************************************
# epoch:  401
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0515 | mape: 5.1474
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.0506 | mape: 5.0567
# ********************************************************
# epoch:  402
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0517 | mape: 5.1666
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0995 | mae: 0.0513 | mape: 5.1281
# ********************************************************
# epoch:  403
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0516 | mape: 5.164
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.0509 | mape: 5.0864
# ********************************************************
# epoch:  404
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.051 | mape: 5.1004
#
# EDGE RECONSTRUCTION TEST => mse: 0.0098 | rmse: 0.0991 | mae: 0.0506 | mape: 5.0617
# ********************************************************
# epoch:  405
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0951 | mae: 0.051 | mape: 5.1018
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1002 | mae: 0.0516 | mape: 5.1637
# ********************************************************
# epoch:  406
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0947 | mae: 0.0507 | mape: 5.065
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.0509 | mape: 5.0863
# ********************************************************
# epoch:  407
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.0513 | mape: 5.1266
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0995 | mae: 0.0517 | mape: 5.1677
# ********************************************************
# epoch:  408
#
# LOSS => l2_loss: 0.0002 | loss: 0.0052
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0951 | mae: 0.051 | mape: 5.0959
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0994 | mae: 0.0513 | mape: 5.133
# ********************************************************
# epoch:  409
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0956 | mae: 0.0513 | mape: 5.1295
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.0513 | mape: 5.1275
# ********************************************************
# epoch:  410
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0089 | rmse: 0.0946 | mae: 0.0508 | mape: 5.083
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.0513 | mape: 5.1287
# ********************************************************
# epoch:  411
#
# LOSS => l2_loss: 0.0001 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0951 | mae: 0.051 | mape: 5.1046
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1003 | mae: 0.0522 | mape: 5.2192
# ********************************************************
# epoch:  412
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.0512 | mape: 5.1177
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.0514 | mape: 5.1385
# ********************************************************
# epoch:  413
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.0513 | mape: 5.129
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0509 | mape: 5.0876
# ********************************************************
# epoch:  414
#
# LOSS => l2_loss: 0.0001 | loss: 0.0052
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0959 | mae: 0.0516 | mape: 5.1587
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1001 | mae: 0.0519 | mape: 5.186
# ********************************************************
# epoch:  415
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0955 | mae: 0.0516 | mape: 5.1565
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1001 | mae: 0.0513 | mape: 5.1264
# ********************************************************
# epoch:  416
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.0507 | mape: 5.0721
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1002 | mae: 0.0514 | mape: 5.1371
# ********************************************************
# epoch:  417
#
# LOSS => l2_loss: 0.0001 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.0512 | mape: 5.1217
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.0507 | mape: 5.0709
# ********************************************************
# epoch:  418
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0958 | mae: 0.0517 | mape: 5.1726
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.0509 | mape: 5.0879
# ********************************************************
# epoch:  419
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0956 | mae: 0.0516 | mape: 5.155
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.051 | mape: 5.1047
# ********************************************************
# epoch:  420
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.0511 | mape: 5.1107
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0995 | mae: 0.0507 | mape: 5.0692
# ********************************************************
# epoch:  421
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0946 | mae: 0.051 | mape: 5.0988
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0993 | mae: 0.0512 | mape: 5.1236
# ********************************************************
# epoch:  422
#
# LOSS => l2_loss: 0.0001 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0958 | mae: 0.0519 | mape: 5.1883
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1002 | mae: 0.0511 | mape: 5.108
# ********************************************************
# epoch:  423
#
# LOSS => l2_loss: 0.0001 | loss: 0.0047
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0957 | mae: 0.0516 | mape: 5.1608
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0994 | mae: 0.0509 | mape: 5.0871
# ********************************************************
# epoch:  424
#
# LOSS => l2_loss: 0.0001 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0513 | mape: 5.1267
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.0514 | mape: 5.1422
# ********************************************************
# epoch:  425
#
# LOSS => l2_loss: 0.0001 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0955 | mae: 0.0513 | mape: 5.1316
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1004 | mae: 0.0514 | mape: 5.1401
# ********************************************************
# epoch:  426
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0955 | mae: 0.0513 | mape: 5.1252
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.0509 | mape: 5.092
# ********************************************************
# epoch:  427
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0961 | mae: 0.0521 | mape: 5.2135
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.0509 | mape: 5.0879
# ********************************************************
# epoch:  428
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.0516 | mape: 5.1639
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1002 | mae: 0.0512 | mape: 5.1237
# ********************************************************
# epoch:  429
#
# LOSS => l2_loss: 0.0002 | loss: 0.0047
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.0515 | mape: 5.1451
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.0511 | mape: 5.1087
# ********************************************************
# epoch:  430
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0511 | mape: 5.1117
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.0518 | mape: 5.1783
# ********************************************************
# epoch:  431
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.095 | mae: 0.0515 | mape: 5.1473
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1005 | mae: 0.0517 | mape: 5.1651
# ********************************************************
# epoch:  432
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0948 | mae: 0.0515 | mape: 5.1513
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0516 | mape: 5.1575
# ********************************************************
# epoch:  433
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0955 | mae: 0.0517 | mape: 5.1737
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.0508 | mape: 5.0801
# ********************************************************
# epoch:  434
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0957 | mae: 0.0516 | mape: 5.1606
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1003 | mae: 0.0522 | mape: 5.2202
# ********************************************************
# epoch:  435
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0957 | mae: 0.0513 | mape: 5.1293
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.0516 | mape: 5.1622
# ********************************************************
# epoch:  436
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0512 | mape: 5.122
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.0511 | mape: 5.1125
# ********************************************************
# epoch:  437
#
# LOSS => l2_loss: 0.0002 | loss: 0.0052
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.0519 | mape: 5.186
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.0516 | mape: 5.1589
# ********************************************************
# epoch:  438
#
# LOSS => l2_loss: 0.0002 | loss: 0.0046
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0949 | mae: 0.0509 | mape: 5.0874
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1005 | mae: 0.0518 | mape: 5.1789
# ********************************************************
# epoch:  439
#
# LOSS => l2_loss: 0.0001 | loss: 0.0047
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.051 | mape: 5.0968
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1006 | mae: 0.0517 | mape: 5.1727
# ********************************************************
# epoch:  440
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0948 | mae: 0.0512 | mape: 5.1229
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1004 | mae: 0.0519 | mape: 5.1892
# ********************************************************
# epoch:  441
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.095 | mae: 0.0506 | mape: 5.0626
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1001 | mae: 0.0513 | mape: 5.1315
# ********************************************************
# epoch:  442
#
# LOSS => l2_loss: 0.0002 | loss: 0.0047
#
# EDGE RECONSTRUCTION VAL => mse: 0.0093 | rmse: 0.0965 | mae: 0.0519 | mape: 5.1918
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0512 | mape: 5.1231
# ********************************************************
# epoch:  443
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0949 | mae: 0.0509 | mape: 5.0938
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0994 | mae: 0.0512 | mape: 5.1151
# ********************************************************
# epoch:  444
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0957 | mae: 0.0512 | mape: 5.1186
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.0507 | mape: 5.0722
# ********************************************************
# epoch:  445
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0955 | mae: 0.0513 | mape: 5.1319
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1001 | mae: 0.0514 | mape: 5.1368
# ********************************************************
# epoch:  446
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0513 | mape: 5.1278
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0512 | mape: 5.1249
# ********************************************************
# epoch:  447
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.0516 | mape: 5.165
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.0512 | mape: 5.1166
# ********************************************************
# epoch:  448
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0957 | mae: 0.0521 | mape: 5.2075
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.0517 | mape: 5.1734
# ********************************************************
# epoch:  449
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.051 | mape: 5.0971
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.0512 | mape: 5.1182
# ********************************************************
# epoch:  450
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0948 | mae: 0.0507 | mape: 5.0712
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.0508 | mape: 5.0773
# ********************************************************
# epoch:  451
#
# LOSS => l2_loss: 0.0001 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0949 | mae: 0.0511 | mape: 5.1073
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1003 | mae: 0.0516 | mape: 5.1622
# ********************************************************
# epoch:  452
#
# LOSS => l2_loss: 0.0001 | loss: 0.0046
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0955 | mae: 0.0514 | mape: 5.1392
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0516 | mape: 5.1552
# ********************************************************
# epoch:  453
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0949 | mae: 0.0512 | mape: 5.1165
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.0513 | mape: 5.1251
# ********************************************************
# epoch:  454
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.0516 | mape: 5.1625
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1006 | mae: 0.0516 | mape: 5.1607
# ********************************************************
# epoch:  455
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.095 | mae: 0.0514 | mape: 5.1374
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.051 | mape: 5.0964
# ********************************************************
# epoch:  456
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.0515 | mape: 5.1482
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0995 | mae: 0.0513 | mape: 5.1261
# ********************************************************
# epoch:  457
#
# LOSS => l2_loss: 0.0001 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0951 | mae: 0.0507 | mape: 5.0659
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1001 | mae: 0.052 | mape: 5.1953
# ********************************************************
# epoch:  458
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.0513 | mape: 5.1349
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.0511 | mape: 5.1066
# ********************************************************
# epoch:  459
#
# LOSS => l2_loss: 0.0001 | loss: 0.0052
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.051 | mape: 5.0994
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1004 | mae: 0.0518 | mape: 5.1769
# ********************************************************
# epoch:  460
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.095 | mae: 0.0512 | mape: 5.122
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1001 | mae: 0.0516 | mape: 5.16
# ********************************************************
# epoch:  461
#
# LOSS => l2_loss: 0.0001 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.052 | mape: 5.1967
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.0512 | mape: 5.1232
# ********************************************************
# epoch:  462
#
# LOSS => l2_loss: 0.0001 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0517 | mape: 5.1714
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.0517 | mape: 5.167
# ********************************************************
# epoch:  463
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.0512 | mape: 5.1152
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.051 | mape: 5.099
# ********************************************************
# epoch:  464
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.095 | mae: 0.051 | mape: 5.0973
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.051 | mape: 5.0973
# ********************************************************
# epoch:  465
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0956 | mae: 0.0515 | mape: 5.1516
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0994 | mae: 0.0512 | mape: 5.1231
# ********************************************************
# epoch:  466
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.0514 | mape: 5.1416
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.0508 | mape: 5.0795
# ********************************************************
# epoch:  467
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0512 | mape: 5.1188
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.0508 | mape: 5.0788
# ********************************************************
# epoch:  468
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.095 | mae: 0.0513 | mape: 5.1341
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.051 | mape: 5.0993
# ********************************************************
# epoch:  469
#
# LOSS => l2_loss: 0.0002 | loss: 0.0052
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.095 | mae: 0.0514 | mape: 5.1418
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.0509 | mape: 5.091
# ********************************************************
# epoch:  470
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0089 | rmse: 0.0945 | mae: 0.051 | mape: 5.0984
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0995 | mae: 0.0517 | mape: 5.168
# ********************************************************
# epoch:  471
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0947 | mae: 0.051 | mape: 5.0994
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1006 | mae: 0.0513 | mape: 5.1266
# ********************************************************
# epoch:  472
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.095 | mae: 0.0515 | mape: 5.1454
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1001 | mae: 0.0513 | mape: 5.133
# ********************************************************
# epoch:  473
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0948 | mae: 0.0515 | mape: 5.153
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.0513 | mape: 5.1265
# ********************************************************
# epoch:  474
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.0515 | mape: 5.1542
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1006 | mae: 0.0514 | mape: 5.1388
# ********************************************************
# epoch:  475
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0959 | mae: 0.0517 | mape: 5.1734
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1001 | mae: 0.0513 | mape: 5.1318
# ********************************************************
# epoch:  476
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0949 | mae: 0.0505 | mape: 5.0481
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.0514 | mape: 5.1395
# ********************************************************
# epoch:  477
#
# LOSS => l2_loss: 0.0001 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0089 | rmse: 0.0944 | mae: 0.0509 | mape: 5.0877
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1004 | mae: 0.0512 | mape: 5.1228
# ********************************************************
# epoch:  478
#
# LOSS => l2_loss: 0.0001 | loss: 0.0047
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0949 | mae: 0.0514 | mape: 5.1388
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.051 | mape: 5.0977
# ********************************************************
# epoch:  479
#
# LOSS => l2_loss: 0.0001 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0957 | mae: 0.0512 | mape: 5.1219
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.0508 | mape: 5.081
# ********************************************************
# epoch:  480
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0089 | rmse: 0.0945 | mae: 0.0509 | mape: 5.0888
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.0506 | mape: 5.0608
# ********************************************************
# epoch:  481
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0951 | mae: 0.0513 | mape: 5.1284
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.0511 | mape: 5.108
# ********************************************************
# epoch:  482
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0949 | mae: 0.0509 | mape: 5.0921
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0514 | mape: 5.1356
# ********************************************************
# epoch:  483
#
# LOSS => l2_loss: 0.0002 | loss: 0.0052
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0947 | mae: 0.051 | mape: 5.0968
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0506 | mape: 5.059
# ********************************************************
# epoch:  484
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.095 | mae: 0.0513 | mape: 5.1311
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.0513 | mape: 5.1298
# ********************************************************
# epoch:  485
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.0511 | mape: 5.1068
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0994 | mae: 0.0511 | mape: 5.1059
# ********************************************************
# epoch:  486
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0958 | mae: 0.0517 | mape: 5.173
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1002 | mae: 0.0515 | mape: 5.1525
# ********************************************************
# epoch:  487
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0949 | mae: 0.0516 | mape: 5.1571
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.0514 | mape: 5.1384
# ********************************************************
# epoch:  488
#
# LOSS => l2_loss: 0.0001 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0955 | mae: 0.0514 | mape: 5.1356
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.0515 | mape: 5.1532
# ********************************************************
# epoch:  489
#
# LOSS => l2_loss: 0.0001 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0951 | mae: 0.0511 | mape: 5.1103
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.0509 | mape: 5.0919
# ********************************************************
# epoch:  490
#
# LOSS => l2_loss: 0.0002 | loss: 0.0047
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.051 | mape: 5.1016
#
# EDGE RECONSTRUCTION TEST => mse: 0.0098 | rmse: 0.0992 | mae: 0.0504 | mape: 5.0409
# ********************************************************
# epoch:  491
#
# LOSS => l2_loss: 0.0001 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.051 | mape: 5.101
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.0509 | mape: 5.0854
# ********************************************************
# epoch:  492
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0948 | mae: 0.0508 | mape: 5.0766
#
# EDGE RECONSTRUCTION TEST => mse: 0.0102 | rmse: 0.1008 | mae: 0.0521 | mape: 5.2138
# ********************************************************
# epoch:  493
#
# LOSS => l2_loss: 0.0002 | loss: 0.0052
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0947 | mae: 0.0507 | mape: 5.073
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0995 | mae: 0.0513 | mape: 5.1285
# ********************************************************
# epoch:  494
#
# LOSS => l2_loss: 0.0001 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0948 | mae: 0.0509 | mape: 5.0926
#
# EDGE RECONSTRUCTION TEST => mse: 0.0098 | rmse: 0.0992 | mae: 0.0508 | mape: 5.0756
# ********************************************************
# epoch:  495
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0089 | rmse: 0.0944 | mae: 0.0507 | mape: 5.0719
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0511 | mape: 5.1076
# ********************************************************
# epoch:  496
#
# LOSS => l2_loss: 0.0001 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0516 | mape: 5.1629
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.0509 | mape: 5.0889
# ********************************************************
# epoch:  497
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0947 | mae: 0.0512 | mape: 5.1212
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.0511 | mape: 5.1145
# ********************************************************
# epoch:  498
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.0515 | mape: 5.1541
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1002 | mae: 0.0511 | mape: 5.114
# ********************************************************
# epoch:  499
#
# LOSS => l2_loss: 0.0001 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0959 | mae: 0.0521 | mape: 5.2076
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1001 | mae: 0.0512 | mape: 5.1212
# ********************************************************
# epoch:  500
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0951 | mae: 0.0509 | mape: 5.0923
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0994 | mae: 0.0508 | mape: 5.0788
# ********************************************************
# epoch:  501
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0949 | mae: 0.0511 | mape: 5.1124
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0511 | mape: 5.1053
# ********************************************************
# epoch:  502
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0089 | rmse: 0.0946 | mae: 0.0508 | mape: 5.0811
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.0506 | mape: 5.0601
# ********************************************************
# epoch:  503
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.0508 | mape: 5.0807
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.0514 | mape: 5.1373
# ********************************************************
# epoch:  504
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.096 | mae: 0.0519 | mape: 5.1924
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.0515 | mape: 5.145
# ********************************************************
# epoch:  505
#
# LOSS => l2_loss: 0.0001 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0089 | rmse: 0.0943 | mae: 0.0511 | mape: 5.1131
#
# EDGE RECONSTRUCTION TEST => mse: 0.0102 | rmse: 0.1008 | mae: 0.052 | mape: 5.1961
# ********************************************************
# epoch:  506
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.0512 | mape: 5.1193
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.0512 | mape: 5.1217
# ********************************************************
# epoch:  507
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0951 | mae: 0.0507 | mape: 5.069
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.051 | mape: 5.0965
# ********************************************************
# epoch:  508
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.095 | mae: 0.0507 | mape: 5.0657
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.051 | mape: 5.1009
# ********************************************************
# epoch:  509
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.095 | mae: 0.0512 | mape: 5.1166
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1006 | mae: 0.0518 | mape: 5.1759
# ********************************************************
# epoch:  510
#
# LOSS => l2_loss: 0.0001 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0089 | rmse: 0.0945 | mae: 0.0514 | mape: 5.1394
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0994 | mae: 0.0508 | mape: 5.0752
# ********************************************************
# epoch:  511
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.095 | mae: 0.051 | mape: 5.1036
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.0515 | mape: 5.1454
# ********************************************************
# epoch:  512
#
# LOSS => l2_loss: 0.0001 | loss: 0.0047
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0951 | mae: 0.0509 | mape: 5.0903
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0513 | mape: 5.1266
# ********************************************************
# epoch:  513
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0948 | mae: 0.0513 | mape: 5.1256
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.0516 | mape: 5.1583
# ********************************************************
# epoch:  514
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0947 | mae: 0.0507 | mape: 5.072
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0995 | mae: 0.0506 | mape: 5.0646
# ********************************************************
# epoch:  515
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0516 | mape: 5.1576
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.051 | mape: 5.1019
# ********************************************************
# epoch:  516
#
# LOSS => l2_loss: 0.0001 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0511 | mape: 5.1056
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.0513 | mape: 5.1282
# ********************************************************
# epoch:  517
#
# LOSS => l2_loss: 0.0001 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0948 | mae: 0.0508 | mape: 5.0778
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.0517 | mape: 5.1684
# ********************************************************
# epoch:  518
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.0511 | mape: 5.1067
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1001 | mae: 0.0507 | mape: 5.074
# ********************************************************
# epoch:  519
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0955 | mae: 0.0513 | mape: 5.1308
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.0509 | mape: 5.09
# ********************************************************
# epoch:  520
#
# LOSS => l2_loss: 0.0001 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0089 | rmse: 0.0944 | mae: 0.0507 | mape: 5.067
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0993 | mae: 0.0509 | mape: 5.0855
# ********************************************************
# epoch:  521
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0089 | rmse: 0.0945 | mae: 0.051 | mape: 5.0985
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1007 | mae: 0.0525 | mape: 5.2542
# ********************************************************
# epoch:  522
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0948 | mae: 0.0515 | mape: 5.1483
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1001 | mae: 0.0517 | mape: 5.1704
# ********************************************************
# epoch:  523
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0088 | rmse: 0.094 | mae: 0.051 | mape: 5.1001
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.0509 | mape: 5.0856
# ********************************************************
# epoch:  524
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0512 | mape: 5.1242
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1001 | mae: 0.0511 | mape: 5.1097
# ********************************************************
# epoch:  525
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0959 | mae: 0.0513 | mape: 5.1284
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0512 | mape: 5.1248
# ********************************************************
# epoch:  526
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.0511 | mape: 5.1131
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.0516 | mape: 5.1633
# ********************************************************
# epoch:  527
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0955 | mae: 0.051 | mape: 5.1009
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0994 | mae: 0.0507 | mape: 5.0718
# ********************************************************
# epoch:  528
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0951 | mae: 0.0512 | mape: 5.115
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1004 | mae: 0.0515 | mape: 5.1482
# ********************************************************
# epoch:  529
#
# LOSS => l2_loss: 0.0002 | loss: 0.0053
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0511 | mape: 5.1137
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1003 | mae: 0.0518 | mape: 5.1791
# ********************************************************
# epoch:  530
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.0514 | mape: 5.1367
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1002 | mae: 0.0513 | mape: 5.1308
# ********************************************************
# epoch:  531
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0513 | mape: 5.1316
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.0506 | mape: 5.0607
# ********************************************************
# epoch:  532
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0948 | mae: 0.0511 | mape: 5.1132
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.0512 | mape: 5.1243
# ********************************************************
# epoch:  533
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0951 | mae: 0.0515 | mape: 5.1519
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.0508 | mape: 5.0792
# ********************************************************
# epoch:  534
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0089 | rmse: 0.0943 | mae: 0.0512 | mape: 5.1184
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1002 | mae: 0.0516 | mape: 5.1578
# ********************************************************
# epoch:  535
#
# LOSS => l2_loss: 0.0001 | loss: 0.0047
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0955 | mae: 0.0515 | mape: 5.1463
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1001 | mae: 0.0515 | mape: 5.1538
# ********************************************************
# epoch:  536
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0961 | mae: 0.052 | mape: 5.2046
#
# EDGE RECONSTRUCTION TEST => mse: 0.0102 | rmse: 0.1008 | mae: 0.0521 | mape: 5.2129
# ********************************************************
# epoch:  537
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0957 | mae: 0.0512 | mape: 5.1244
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0515 | mape: 5.1536
# ********************************************************
# epoch:  538
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0949 | mae: 0.052 | mape: 5.1962
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1004 | mae: 0.052 | mape: 5.2044
# ********************************************************
# epoch:  539
#
# LOSS => l2_loss: 0.0002 | loss: 0.0047
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0956 | mae: 0.0512 | mape: 5.1232
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0994 | mae: 0.0507 | mape: 5.0741
# ********************************************************
# epoch:  540
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.0508 | mape: 5.0821
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0995 | mae: 0.0512 | mape: 5.1221
# ********************************************************
# epoch:  541
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0957 | mae: 0.0513 | mape: 5.1278
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0995 | mae: 0.0511 | mape: 5.1095
# ********************************************************
# epoch:  542
#
# LOSS => l2_loss: 0.0002 | loss: 0.0046
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0955 | mae: 0.0512 | mape: 5.1155
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0993 | mae: 0.0512 | mape: 5.1162
# ********************************************************
# epoch:  543
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0089 | rmse: 0.0943 | mae: 0.0511 | mape: 5.1053
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0511 | mape: 5.108
# ********************************************************
# epoch:  544
#
# LOSS => l2_loss: 0.0002 | loss: 0.0052
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.0509 | mape: 5.0851
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.0512 | mape: 5.1159
# ********************************************************
# epoch:  545
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0946 | mae: 0.0509 | mape: 5.0898
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.0511 | mape: 5.1083
# ********************************************************
# epoch:  546
#
# LOSS => l2_loss: 0.0002 | loss: 0.0052
#
# EDGE RECONSTRUCTION VAL => mse: 0.0094 | rmse: 0.0969 | mae: 0.053 | mape: 5.2962
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1003 | mae: 0.051 | mape: 5.0968
# ********************************************************
# epoch:  547
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0959 | mae: 0.0518 | mape: 5.1794
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1002 | mae: 0.0515 | mape: 5.1543
# ********************************************************
# epoch:  548
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.096 | mae: 0.0519 | mape: 5.1897
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1001 | mae: 0.0514 | mape: 5.1377
# ********************************************************
# ...
# epoch:  942
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0947 | mae: 0.051 | mape: 5.103
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0994 | mae: 0.0507 | mape: 5.0661
# ********************************************************
# epoch:  943
#
# LOSS => l2_loss: 0.0001 | loss: 0.0052
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.0518 | mape: 5.1805
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0512 | mape: 5.1171
# ********************************************************
# epoch:  944
#
# LOSS => l2_loss: 0.0001 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0948 | mae: 0.051 | mape: 5.1018
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.051 | mape: 5.097
# ********************************************************
# epoch:  945
#
# LOSS => l2_loss: 0.0001 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0956 | mae: 0.0518 | mape: 5.1844
#
# EDGE RECONSTRUCTION TEST => mse: 0.0102 | rmse: 0.1008 | mae: 0.052 | mape: 5.1974
# ********************************************************
# epoch:  946
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0951 | mae: 0.0512 | mape: 5.1226
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0511 | mape: 5.1061
# ********************************************************
# epoch:  947
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0955 | mae: 0.0514 | mape: 5.1384
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0513 | mape: 5.1274
# ********************************************************
# epoch:  948
#
# LOSS => l2_loss: 0.0001 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0517 | mape: 5.1724
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1006 | mae: 0.0518 | mape: 5.1845
# ********************************************************
# epoch:  949
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0089 | rmse: 0.0945 | mae: 0.0507 | mape: 5.0688
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1005 | mae: 0.0513 | mape: 5.1346
# ********************************************************
# epoch:  950
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0956 | mae: 0.0516 | mape: 5.1625
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.0512 | mape: 5.121
# ********************************************************
# epoch:  951
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0957 | mae: 0.0513 | mape: 5.1306
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0995 | mae: 0.0514 | mape: 5.1372
# ********************************************************
# epoch:  952
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.0515 | mape: 5.1493
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1002 | mae: 0.0518 | mape: 5.1777
# ********************************************************
# epoch:  953
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.095 | mae: 0.0509 | mape: 5.0946
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1002 | mae: 0.052 | mape: 5.1987
# ********************************************************
# epoch:  954
#
# LOSS => l2_loss: 0.0001 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0955 | mae: 0.0514 | mape: 5.1363
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1004 | mae: 0.0517 | mape: 5.1685
# ********************************************************
# epoch:  955
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0951 | mae: 0.0516 | mape: 5.1568
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0995 | mae: 0.0511 | mape: 5.1106
# ********************************************************
# epoch:  956
#
# LOSS => l2_loss: 0.0001 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.0516 | mape: 5.1642
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.0515 | mape: 5.154
# ********************************************************
# epoch:  957
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0958 | mae: 0.0521 | mape: 5.2101
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.0515 | mape: 5.147
# ********************************************************
# epoch:  958
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0947 | mae: 0.0509 | mape: 5.0891
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.0511 | mape: 5.1112
# ********************************************************
# epoch:  959
#
# LOSS => l2_loss: 0.0001 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0951 | mae: 0.0512 | mape: 5.1237
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.051 | mape: 5.0971
# ********************************************************
# epoch:  960
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0955 | mae: 0.0518 | mape: 5.1822
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1006 | mae: 0.0521 | mape: 5.2122
# ********************************************************
# epoch:  961
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0955 | mae: 0.0514 | mape: 5.1376
#
# EDGE RECONSTRUCTION TEST => mse: 0.0102 | rmse: 0.1009 | mae: 0.0519 | mape: 5.1932
# ********************************************************
# epoch:  962
#
# LOSS => l2_loss: 0.0001 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0959 | mae: 0.0517 | mape: 5.1721
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.0519 | mape: 5.194
# ********************************************************
# epoch:  963
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0955 | mae: 0.0513 | mape: 5.1259
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1001 | mae: 0.0509 | mape: 5.0928
# ********************************************************
# epoch:  964
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0513 | mape: 5.13
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1003 | mae: 0.0516 | mape: 5.1582
# ********************************************************
# epoch:  965
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0951 | mae: 0.0513 | mape: 5.1276
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1007 | mae: 0.0525 | mape: 5.2459
# ********************************************************
# epoch:  966
#
# LOSS => l2_loss: 0.0001 | loss: 0.0052
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.0513 | mape: 5.1252
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1003 | mae: 0.0512 | mape: 5.1205
# ********************************************************
# epoch:  967
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0962 | mae: 0.052 | mape: 5.1996
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0993 | mae: 0.0508 | mape: 5.0763
# ********************************************************
# epoch:  968
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0957 | mae: 0.0511 | mape: 5.1096
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0995 | mae: 0.0512 | mape: 5.1158
# ********************************************************
# epoch:  969
#
# LOSS => l2_loss: 0.0001 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.0519 | mape: 5.1922
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.0513 | mape: 5.1317
# ********************************************************
# epoch:  970
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0957 | mae: 0.0516 | mape: 5.1619
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0508 | mape: 5.0778
# ********************************************************
# epoch:  971
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.0515 | mape: 5.1514
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.0519 | mape: 5.1936
# ********************************************************
# epoch:  972
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0514 | mape: 5.1421
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0508 | mape: 5.079
# ********************************************************
# epoch:  973
#
# LOSS => l2_loss: 0.0001 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.096 | mae: 0.052 | mape: 5.195
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1002 | mae: 0.0516 | mape: 5.1568
# ********************************************************
# epoch:  974
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0959 | mae: 0.0516 | mape: 5.1552
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.0514 | mape: 5.1429
# ********************************************************
# epoch:  975
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.095 | mae: 0.0514 | mape: 5.1379
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0517 | mape: 5.1669
# ********************************************************
# epoch:  976
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.095 | mae: 0.0507 | mape: 5.0655
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.0511 | mape: 5.111
# ********************************************************
# epoch:  977
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0946 | mae: 0.0506 | mape: 5.0617
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.0519 | mape: 5.1878
# ********************************************************
# epoch:  978
#
# LOSS => l2_loss: 0.0002 | loss: 0.0052
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0947 | mae: 0.0506 | mape: 5.0625
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.0511 | mape: 5.1061
# ********************************************************
# epoch:  979
#
# LOSS => l2_loss: 0.0001 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0958 | mae: 0.0515 | mape: 5.153
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.0518 | mape: 5.1762
# ********************************************************
# epoch:  980
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0949 | mae: 0.0516 | mape: 5.1642
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0993 | mae: 0.0506 | mape: 5.0632
# ********************************************************
# epoch:  981
#
# LOSS => l2_loss: 0.0002 | loss: 0.0046
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0951 | mae: 0.0513 | mape: 5.1344
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1004 | mae: 0.0514 | mape: 5.1391
# ********************************************************
# epoch:  982
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.0512 | mape: 5.1182
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.051 | mape: 5.1038
# ********************************************************
# epoch:  983
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.0509 | mape: 5.0917
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1003 | mae: 0.0512 | mape: 5.1242
# ********************************************************
# epoch:  984
#
# LOSS => l2_loss: 0.0001 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0958 | mae: 0.052 | mape: 5.2042
#
# EDGE RECONSTRUCTION TEST => mse: 0.0098 | rmse: 0.0992 | mae: 0.051 | mape: 5.0977
# ********************************************************
# epoch:  985
#
# LOSS => l2_loss: 0.0002 | loss: 0.0052
#
# EDGE RECONSTRUCTION VAL => mse: 0.0089 | rmse: 0.0945 | mae: 0.051 | mape: 5.0996
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0993 | mae: 0.0511 | mape: 5.1125
# ********************************************************
# epoch:  986
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0951 | mae: 0.0508 | mape: 5.0773
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1003 | mae: 0.0518 | mape: 5.1837
# ********************************************************
# epoch:  987
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0952 | mae: 0.0508 | mape: 5.0848
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0507 | mape: 5.0726
# ********************************************************
# epoch:  988
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0951 | mae: 0.0516 | mape: 5.1626
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.0515 | mape: 5.1511
# ********************************************************
# epoch:  989
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0955 | mae: 0.0518 | mape: 5.1793
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0997 | mae: 0.0511 | mape: 5.1124
# ********************************************************
# epoch:  990
#
# LOSS => l2_loss: 0.0002 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0948 | mae: 0.0507 | mape: 5.0654
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0999 | mae: 0.0512 | mape: 5.116
# ********************************************************
# epoch:  991
#
# LOSS => l2_loss: 0.0001 | loss: 0.0047
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0955 | mae: 0.0513 | mape: 5.1324
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.0509 | mape: 5.0899
# ********************************************************
# epoch:  992
#
# LOSS => l2_loss: 0.0001 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.0517 | mape: 5.1657
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0996 | mae: 0.0517 | mape: 5.1697
# ********************************************************
# epoch:  993
#
# LOSS => l2_loss: 0.0001 | loss: 0.0047
#
# EDGE RECONSTRUCTION VAL => mse: 0.0092 | rmse: 0.0957 | mae: 0.0516 | mape: 5.1637
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.0998 | mae: 0.0512 | mape: 5.1167
# ********************************************************
# epoch:  994
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.009 | rmse: 0.0948 | mae: 0.0509 | mape: 5.0863
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1001 | mae: 0.051 | mape: 5.1039
# ********************************************************
# epoch:  995
#
# LOSS => l2_loss: 0.0001 | loss: 0.005
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0955 | mae: 0.0515 | mape: 5.1525
#
# EDGE RECONSTRUCTION TEST => mse: 0.01 | rmse: 0.1 | mae: 0.0511 | mape: 5.1056
# ********************************************************
# epoch:  996
#
# LOSS => l2_loss: 0.0002 | loss: 0.0048
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0956 | mae: 0.0516 | mape: 5.163
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0993 | mae: 0.0506 | mape: 5.0629
# ********************************************************
# epoch:  997
#
# LOSS => l2_loss: 0.0002 | loss: 0.0051
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0954 | mae: 0.0514 | mape: 5.1427
#
# EDGE RECONSTRUCTION TEST => mse: 0.0101 | rmse: 0.1005 | mae: 0.0513 | mape: 5.1317
# ********************************************************
# epoch:  998
#
# LOSS => l2_loss: 0.0002 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0953 | mae: 0.0512 | mape: 5.1218
#
# EDGE RECONSTRUCTION TEST => mse: 0.0099 | rmse: 0.0995 | mae: 0.0512 | mape: 5.1166
# ********************************************************
# epoch:  999
#
# LOSS => l2_loss: 0.0001 | loss: 0.0049
#
# EDGE RECONSTRUCTION VAL => mse: 0.0091 | rmse: 0.0955 | mae: 0.0511 | mape: 5.111
#
# EDGE RECONSTRUCTION TEST => mse: 0.0098 | rmse: 0.0992 | mae: 0.0505 | mape: 5.0465
# Total Execution Time: 0:12:19.008990
